# %%
import pandas as pd
import numpy as np
import pickle
import math

# %% [markdown]
# # Webdata

# %%
df_web = []

for i in range(1, 8):
    
    df_web.append(pd.read_csv(r"Q:\Meine Bibliotheken\Research\Projects\Ausgründungen\02_Data\02_Webdata2IPC\webdata\ARGUS_chunk_p" + str(i) + ".csv"
                 ,sep="\t"
                 ,encoding="utf-8"))

# %%
df_web = pd.concat(df_web)

# %%
# Drop rows with NaN in text column
df_web = df_web.loc[df_web.text.notnull(),:]

# %%
df_web.head(3)
# Out:
#             ID  dl_rank              dl_slot alias error redirect  \
# 9   6050132315        0     medcom-online.de   NaN  None    False
# 11  8270118111        0  bohnacker-group.com   NaN  None    False
# 12  2010636962        0        aca-berlin.de   NaN  None    False
#
#                            start_page  \
# 9   http://medcom-online.de/home.html
# 11         http://bohnacker-group.com
# 12         https://www.aca-berlin.de/
#
#                                                 title keywords  \
# 9                                                 NaN      NaN
# 11                Domain im Kundenauftrag registriert      NaN
# 12  Naturheilmittel - Superfoods - Gesundheit - Er...      NaN
#
#                                  description  \
# 9                                        NaN
# 11  Domain registriert bei united-domains.de
# 12                                       NaN
#
#                                                  text  \
# 9                               [->p<-] © 2019 MedCom
# 11  [->p<-] Diese Seite wurde automatisch erstellt...
# 12  [->p<-] Ich habe des Öfteren die Frage erhalte...
#
#                                                 links  \
# 9          biopsee.de,typo3.p476113.webspaceconfig.de
# 11                                  united-domains.de
# 12  sdw-berlin.de,manuka-honig.net,msm-dmso.com,na...
#
#                    timestamp                                url
# 9   Mon Jun 29 15:05:44 2020  http://medcom-online.de/home.html
# 11  Mon Jun 29 15:05:47 2020         http://bohnacker-group.com
# 12  Mon Jun 29 15:05:49 2020         https://www.aca-berlin.de/

# %%
# Aggregate webdata by crefo
df_web = df_web.groupby('ID').agg(
    dict(
        text = lambda x: ' '.join(x),
        links = lambda x: list(x)
        )
)

# %%
# Rename ID to crefo and define as column
df_web = df_web.reset_index().rename(columns={"ID": "crefo"})

# %%
df_web
# Out:
#             crefo                                               text  \
# 0      2010000212  [->p<-] WITELS-ALBERT GmbH [->p<-] Malteserstr...
# 1      2010000478  [->p<-] Wir sind die Experten für Gebäudeautom...
# 2      2010000487  [->p<-] CommScope solutions work best when the...
# 3      2010000581  [->p<-] Zur globalen Siemens Website [->p<-] Z...
# 4      2010001061  [->p<-] #AtHomeWithNeumann [->p<-] #AtHomeWith...
# ...           ...                                                ...
# 14567  8350327669  [->p<-] Our technology allows you to provide a...
# 14568  8350330394  [->p<-] Die [->p<-] Dübelgeneration [->p<-] Au...
# 14569  8350331750  [->div<-] line [->div<-] line [->div<-] line [...
# 14570  8350342977  [->p<-] Danke für Ihre Nachricht! [->p<-] UBPM...
# 14571  8350352586  [->p<-] Der Schutz Ihrer personenbezogenen Dat...
#
#                                                    links
# 0      [how2straight.com,twitter.com,instagram.com, h...
# 1      [lsa.hu,aura.lv,roven.by,isloft.is,bahrekar.ir...
# 2      [es.commscope.com,de.commscope.com,fr.commscop...
# 3      [twitter.com,facebook.com,instagram.com,youtub...
# 4      [u67.neumann.com,de-de.neumann.com,en-de.neuma...
# ...                                                  ...
# 14567  [goo.gl,b3emlm.myraidbox.de,steinwurf.com,cada...
# 14568  [dreiburschn.de,drehfix-shop.com,facebook.com,...
# 14569  [youtube.com,facebook.com,dhl.de, youtube.com,...
# 14570  [activemind.de,bfdi.bund.de, activemind.de,bfd...
# 14571  [amerika21.de,regenwald.org,welt.de,cerion-neu...
#
# [14572 rows x 3 columns]

# %% [markdown]
# # Merge Data

# %%
df_epovvc = pd.read_pickle(r"Q:\Meine Bibliotheken\Research\Projects\Ausgründungen\02_Data\02_Webdata2IPC\df_epovvc_s0.pkl")

# %%
df_epovvc.head(3)
# Out:
#    person_id       crefo  equal  bestcrefo  appln_id appln_kind  appln_fili  \
# 0         20  2150355978      1          1  16996827          A  1993-04-07
# 1         20  2150355978      1          1  16996827          A  1993-04-07
# 2         20  2150355978      1          1  16996827          A  1993-04-07
#
#    inpadoc_fa  earliest_f granted technology          ipc
# 0    11221689  1992-04-07       Y          2  H04J   3/00
# 1    11221689  1992-04-07       Y          2  H04J   3/06
# 2    11221689  1992-04-07       Y          2  H04L   5/22

# %%
df = df_epovvc.merge(df_web, how = "left")

# %%
# Write data
with open(r'Q:\Meine Bibliotheken\Research\Projects\Ausgründungen\02_Data\02_Webdata2IPC\df_epovvc_s1.pkl', 'wb') as f:
    pickle.dump(obj=df, file=f)
